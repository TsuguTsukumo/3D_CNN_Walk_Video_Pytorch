# %%
import sys
import os 
print(os.getcwd())
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
sys.path.append('..')

import torch
# Out:
# /workspace/project/misc

# %%
print(os.getcwd())
from models.pytorchvideo_models import WalkVideoClassificationLightningModule
from dataloader.data_loader import WalkDataModule

from pytorch_lightning import Trainer

from IPython.display import clear_output

clear_output()

import torchmetrics

# %%
from pytorch_lightning import seed_everything

seed_everything(42, workers=True)
# Out:
# Global seed set to 42
# 42

# %%
from parameters import get_parameters
from pytorch_grad_cam import GradCAM, HiResCAM, FullGrad, GradCAMPlusPlus, AblationCAM, ScoreCAM, LayerCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap
import torchvision
import cv2
from torchvision import models
from torchvision import transforms
from captum.attr import visualization as viz


VIDEO_LENGTH = ['1', '2', '3']
VIDEO_FRAME = ['8', '16', '32']

opt, _ = get_parameters()
opt.num_workers = 4
opt.batch_size = 8
opt.gpu_num = 1

opt.version = '1201_1_16'
opt.model = "resnet"
opt.model_depth = 50
opt.model_class_num = 1

# opt.clip_duration = 2
# opt.uniform_temporal_subsample_num = 30
opt.version = opt.version + '_' + opt.model + '_depth' + str(opt.model_depth)

opt.fusion_method = 'slow_fusion'
opt.fix_layer = 'all'
# opt.train_path = '/workspace/data/split_pad_dataset_512/fold3/'

opt.transfor_learning = True
opt.pre_process_flag = True

DATA_PATH = opt.split_pad_data_path
opt.train_path = os.path.join(DATA_PATH, 'fold3')

opt.clip_duration = int(1)
opt.uniform_temporal_subsample_num = int(8)

ckpt_path = '/workspace/project/logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt'

# 分類結果フォルダの作成
heatmap_out_dir = '/workspace/data/heatmap' 
directories = [
    os.path.join(heatmap_out_dir, 'Success', 'pred_ASD_as_ASD'),
    os.path.join(heatmap_out_dir, 'Success', 'pred_ASDNot_as_ASDNot'),
    os.path.join(heatmap_out_dir, 'Failure', 'pred_ASD_as_ASDNot'),
    os.path.join(heatmap_out_dir, 'Failure', 'pred_ASDNot_as_ASD')
]

for dir_path in directories:
    os.makedirs(dir_path, exist_ok=True)

print('#' * 50)
print('the data path: %s' % opt.train_path)
print('ckpt: %s' % ckpt_path)


while True:
    files = os.listdir(DATA_PATH)
    if files:
        # 予測ラベル: pred_label
        for i in range(8):
            model = WalkVideoClassificationLightningModule(opt).load_from_checkpoint(ckpt_path)
            data_module = WalkDataModule(opt)
            data_module.setup()
            test_data = data_module.val_dataloader()
            batch = next(iter(test_data))
            video = batch['video'].detach() # b, c, t, h, w
            input_tensor = video[i].unsqueeze(dim=0).cuda()
            label = batch['label'].detach() # b, class num
            y_hat = model.model(video)
            y_hat_sigmoid = torch.sigmoid(y_hat)
            pred_label = torch.where(y_hat_sigmoid >= 0.5, torch.tensor(1), torch.tensor(0))
            out_label = pred_label[i]
            inp_label = label[i]
            print("video_path:", batch['video_name'][i])
            print("input_label:", batch['label'][i])
            print('batch:'+str(i))            
            print('input_tensor:', input_tensor.shape)
            #TODO
            video_name = os.path.join(DATA_PATH, 'fold3')
            if inp_label == 0:
                video_name = os.path.join(video_name, 'val/ASD')
                video_name = os.path.join(video_name, batch['video_name'][i])
            else:
                video_name = os.path.join(video_name, 'val/ASD_not')
                video_name = os.path.join(video_name, batch['video_name'][i])
            
            if out_label != inp_label:
                target_layer = [model.model.blocks[-2].res_blocks[-1]]
                cam = LayerCAM(model, target_layer)
                targets = [ClassifierOutputTarget(-1)]
                grayscale_cam = cam(input_tensor, aug_smooth=True, eigen_smooth=True)
                inp_tensor = input_tensor.squeeze().permute(1,2,3,0)[2].cpu().detach().numpy()
                cam_map = grayscale_cam.mean(axis=1).squeeze()
                cam_map = np.expand_dims(cam_map, 2)
                figure, axis = viz.visualize_image_attr_multiple(
                    cam_map,
                    inp_tensor,
                    methods=['original_image', 'blended_heat_map'],
                    signs=['all', 'positive'],
                    show_colorbar=True,
                    outlier_perc=1, 
                    cmap='jet',
                    titles = ['original image', 'GradCAM++, true label %s, pred label %s' % (int(inp_label), int(out_label))]
                )
                output_heatmap_path = heatmap_out_dir
                output_heatmap_path = os.path.join(output_heatmap_path, 'Failure')
                if inp_label == 0:
                    output_heatmap_path = os.path.join(output_heatmap_path, 'pred_ASD_as_ASDNot')
                    output_heatmap_path = os.path.join(output_heatmap_path, batch["video_name"][i])
                    output_heatmap_path = output_heatmap_path + 'heatmap.png'
                    figure.savefig(output_heatmap_path)
                elif inp_label == 1:
                    output_heatmap_path = os.path.join(output_heatmap_path, 'pred_ASDNot_as_ASD')
                    output_heatmap_path = os.path.join(output_heatmap_path, batch["video_name"][i])
                    output_heatmap_path = output_heatmap_path + 'heatmap.png'
                    figure.savefig(output_heatmap_path)
                #os.remove(video_name)
                continue
            else:
                print("success")
                #os.remove(video_name)


    else:
        print("No videos remain")
        break
# Out:
# ##################################################
# the data path: /workspace/data/split_pad_dataset_512/cord_test
# ckpt: /workspace/project/logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_175.mp4
# input_label: tensor(0)
# batch:0
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_85.mp4
# input_label: tensor(0)
# batch:1
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_191.mp4
# input_label: tensor(0)
# batch:2
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_141.mp4
# input_label: tensor(0)
# batch:3
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_187.mp4
# input_label: tensor(0)
# batch:4
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_50.mp4
# input_label: tensor(0)
# batch:5
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_157.mp4
# input_label: tensor(0)
# batch:6
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_10.mp4
# input_label: tensor(0)
# batch:7
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_78.mp4
# input_label: tensor(0)
# batch:0
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_188.mp4
# input_label: tensor(0)
# batch:1
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_137.mp4
# input_label: tensor(0)
# batch:2
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_82.mp4
# input_label: tensor(0)
# batch:3
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_47.mp4
# input_label: tensor(0)
# batch:4
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_152.mp4
# input_label: tensor(0)
# batch:5
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# WARN:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_145.mp4
# input_label: tensor(0)
# batch:6
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_135.mp4
# input_label: tensor(0)
# batch:7
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# WARN:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: ASD_not_val_1.mp4
# input_label: tensor(1)
# batch:0
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_166.mp4
# input_label: tensor(0)
# batch:1
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_46.mp4
# input_label: tensor(0)
# batch:2
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_201.mp4
# input_label: tensor(0)
# batch:3
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_159.mp4
# input_label: tensor(0)
# batch:4
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_14.mp4
# input_label: tensor(0)
# batch:5
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_196.mp4
# input_label: tensor(0)
# batch:6
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_70.mp4
# input_label: tensor(0)
# batch:7
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_123.mp4
# input_label: tensor(0)
# batch:0
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_159.mp4
# input_label: tensor(0)
# batch:1
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_17.mp4
# input_label: tensor(0)
# batch:2
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_155.mp4
# input_label: tensor(0)
# batch:3
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_109.mp4
# input_label: tensor(0)
# batch:4
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_136.mp4
# input_label: tensor(0)
# batch:5
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_176.mp4
# input_label: tensor(0)
# batch:6
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: ASD_not_val_0.mp4
# input_label: tensor(1)
# batch:7
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_7.mp4
# input_label: tensor(0)
# batch:0
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_0.mp4
# input_label: tensor(0)
# batch:1
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_206.mp4
# input_label: tensor(0)
# batch:2
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# WARN:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_124.mp4
# input_label: tensor(0)
# batch:3
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_73.mp4
# input_label: tensor(0)
# batch:4
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_122.mp4
# input_label: tensor(0)
# batch:5
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_27.mp4
# input_label: tensor(0)
# batch:6
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_108.mp4
# input_label: tensor(0)
# batch:7
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_188.mp4
# input_label: tensor(0)
# batch:0
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_44.mp4
# input_label: tensor(0)
# batch:1
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_87.mp4
# input_label: tensor(0)
# batch:2
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_34.mp4
# input_label: tensor(0)
# batch:3
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_57.mp4
# input_label: tensor(0)
# batch:4
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_96.mp4
# input_label: tensor(0)
# batch:5
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_177.mp4
# input_label: tensor(0)
# batch:6
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_96.mp4
# input_label: tensor(0)
# batch:7
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_58.mp4
# input_label: tensor(0)
# batch:0
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_93.mp4
# input_label: tensor(0)
# batch:1
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# WARN:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_161.mp4
# input_label: tensor(0)
# batch:2
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# WARN:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_81.mp4
# input_label: tensor(0)
# batch:3
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_163.mp4
# input_label: tensor(0)
# batch:4
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# WARN:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_203.mp4
# input_label: tensor(0)
# batch:5
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_48.mp4
# input_label: tensor(0)
# batch:6
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# WARN:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_64.mp4
# input_label: tensor(0)
# batch:7
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_100.mp4
# input_label: tensor(0)
# batch:0
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_41.mp4
# input_label: tensor(0)
# batch:1
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# WARN:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# video_path: 20171211_full_lat_41.mp4
# input_label: tensor(0)
# batch:2
# input_tensor: torch.Size([1, 3, 8, 224, 224])
# success
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../logs/resnet/1119_1_8_resnet_depth50/flod2/checkpoints/epoch=11-val_loss=0.63-val_acc=0.8926.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# ##################################################
# run pre process model! /workspace/data/split_pad_dataset_512/cord_test
# ##################################################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 65>()
#      75 input_tensor = video[i].unsqueeze(dim=0).cuda()
#      76 label = batch['label'].detach() # b, class num
# ---> 77 y_hat = model.model(video)
#      78 y_hat_sigmoid = torch.sigmoid(y_hat)
#      79 pred_label = torch.where(y_hat_sigmoid >= 0.5, torch.tensor(1), torch.tensor(0))
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/dist-packages/pytorchvideo/models/net.py:43, in Net.forward(self, x)
#      41 def forward(self, x: torch.Tensor) -> torch.Tensor:
#      42     for idx in range(len(self.blocks)):
# ---> 43         x = self.blocks[idx](x)
#      44     return x
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/dist-packages/pytorchvideo/models/resnet.py:1393, in ResStage.forward(self, x)
#    1391 def forward(self, x: torch.Tensor) -> torch.Tensor:
#    1392     for _, res_block in enumerate(self.res_blocks):
# -> 1393         x = res_block(x)
#    1394     return x
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/dist-packages/pytorchvideo/models/resnet.py:1175, in ResBlock.forward(self, x)
#    1173 def forward(self, x) -> torch.Tensor:
#    1174     if self.branch1_conv is None:
# -> 1175         x = self.branch_fusion(x, self.branch2(x))
#    1176     else:
#    1177         shortcut = self.branch1_conv(x)
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/dist-packages/pytorchvideo/models/resnet.py:1342, in BottleneckBlock.forward(self, x)
#    1339 def forward(self, x: torch.Tensor) -> torch.Tensor:
#    1340     # Explicitly forward every layer.
#    1341     # Branch2a, for example Tx1x1, BN, ReLU.
# -> 1342     x = self.conv_a(x)
#    1343     if self.norm_a is not None:
#    1344         x = self.norm_a(x)
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/conv.py:607, in Conv3d.forward(self, input)
#     606 def forward(self, input: Tensor) -> Tensor:
# --> 607     return self._conv_forward(input, self.weight, self.bias)
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/conv.py:602, in Conv3d._conv_forward(self, input, weight, bias)
#     590 if self.padding_mode != "zeros":
#     591     return F.conv3d(
#     592         F.pad(
#     593             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     600         self.groups,
#     601     )
# --> 602 return F.conv3d(
#     603     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     604 )
#
# KeyboardInterrupt:
